# %%
#import libraries
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
glob(r'C:\Users\deepe\OneDrive\Desktop\NLP\New folder\*')
# Out:
# ['C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-04.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-05.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-06.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-07.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-08.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-11.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-12.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-13.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-14.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-15.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-18.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-19.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-20.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-21.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-25.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-27.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-28.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-29.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-02-01.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-02-02.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-02-03.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-02-04.parquet',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-02-05.parquet']

# %%
df = pd.read_parquet(f"C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\New folder\\New folder_2021-01-04.parquet")

# %%
df.notna()
# Out:
#         ticker  datetime  date  time  open  high   low  close  volume  \
# 0         True      True  True  True  True  True  True   True    True
# 1         True      True  True  True  True  True  True   True    True
# 2         True      True  True  True  True  True  True   True    True
# 3         True      True  True  True  True  True  True   True    True
# 4         True      True  True  True  True  True  True   True    True
# ...        ...       ...   ...   ...   ...   ...   ...    ...     ...
# 503053    True      True  True  True  True  True  True   True    True
# 503054    True      True  True  True  True  True  True   True    True
# 503055    True      True  True  True  True  True  True   True    True
# 503056    True      True  True  True  True  True  True   True    True
# 503057    True      True  True  True  True  True  True   True    True
#
#         open_interest  strike_price  instrument_type  expiry_date  \
# 0                True          True             True         True
# 1                True          True             True         True
# 2                True          True             True         True
# 3                True          True             True         True
# 4                True          True             True         True
# ...               ...           ...              ...          ...
# 503053           True         False             True         True
# 503054           True         False             True         True
# 503055           True         False             True         True
# 503056           True         False             True         True
# 503057           True         False             True         True
#
#         instrument_name  expiry_type
# 0                  True        False
# 1                  True        False
# 2                  True        False
# 3                  True        False
# 4                  True        False
# ...                 ...          ...
# 503053             True         True
# 503054             True         True
# 503055             True         True
# 503056             True         True
# 503057             True         True
#
# [497432 rows x 15 columns]

# %%
df[df['expiry_type'].isnull()]
df
# Out:
#                        ticker            datetime        date      time  \
# 0       AARTIIND28JAN211200PE 2021-01-04 09:24:00  2021-01-04  09:24:00
# 1       AARTIIND28JAN211200PE 2021-01-04 09:40:00  2021-01-04  09:40:00
# 2       AARTIIND28JAN211200PE 2021-01-04 09:44:00  2021-01-04  09:44:00
# 3       AARTIIND28JAN211200PE 2021-01-04 09:54:00  2021-01-04  09:54:00
# 4       AARTIIND28JAN211200PE 2021-01-04 10:12:00  2021-01-04  10:12:00
# ...                       ...                 ...         ...       ...
# 503053               ZEEL-III 2021-01-04 11:05:00  2021-01-04  11:05:00
# 503054               ZEEL-III 2021-01-04 12:00:00  2021-01-04  12:00:00
# 503055               ZEEL-III 2021-01-04 12:13:00  2021-01-04  12:13:00
# 503056               ZEEL-III 2021-01-04 14:32:00  2021-01-04  14:32:00
# 503057               ZEEL-III 2021-01-04 15:16:00  2021-01-04  15:16:00
#
#           open    high     low   close  volume  open_interest  strike_price  \
# 0        24.05   24.05   24.05   24.05     425           3825        1200.0
# 1        24.05   24.10   24.05   24.10     425           4250        1200.0
# 2        24.10   24.10   24.00   24.00     425           4250        1200.0
# 3        24.00   24.00   21.05   21.05     425           4675        1200.0
# 4        21.05   21.75   21.05   21.75     425           5100        1200.0
# ...        ...     ...     ...     ...     ...            ...           ...
# 503053  221.00  221.00  221.00  221.00    3000              0           NaN
# 503054  221.00  221.00  220.15  220.15    3000           3000           NaN
# 503055  220.15  220.60  220.15  220.60    6000           3000           NaN
# 503056  220.60  222.75  220.60  222.75    3000           9000           NaN
# 503057  222.75  222.75  221.80  221.80    3000          12000           NaN
#
#        instrument_type expiry_date instrument_name expiry_type
# 0                   PE  2021-01-28        AARTIIND        None
# 1                   PE  2021-01-28        AARTIIND        None
# 2                   PE  2021-01-28        AARTIIND        None
# 3                   PE  2021-01-28        AARTIIND        None
# 4                   PE  2021-01-28        AARTIIND        None
# ...                ...         ...             ...         ...
# 503053             FUT  2021-03-25            ZEEL         III
# 503054             FUT  2021-03-25            ZEEL         III
# 503055             FUT  2021-03-25            ZEEL         III
# 503056             FUT  2021-03-25            ZEEL         III
# 503057             FUT  2021-03-25            ZEEL         III
#
# [497432 rows x 15 columns]

# %%
print(na)

# %%
#check the files 
glob(r'C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo_2019-20_data\*')
# Out:
# ['C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-01.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-02.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-03.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-04.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-07.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-08.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-09.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-10.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-11.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-14.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-15.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-16.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-17.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-18.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-21.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-22.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-23.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-24.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-25.pkl',
#  'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-28.pkl']

# %%
# creating data frame 
df = pd.DataFrame(glob(r'C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo_2019-20_data\*'))
df
# Out:
#                                                     0
# 0   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 1   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 2   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 3   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 4   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 5   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 6   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 7   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 8   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 9   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 10  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 11  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 12  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 13  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 14  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 15  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 16  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 17  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 18  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 19  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...

# %%
#Rename the column to location 
df.columns = ['location']
df
# Out:
#                                              location
# 0   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 1   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 2   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 3   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 4   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 5   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 6   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 7   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 8   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 9   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 10  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 11  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 12  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 13  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 14  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 15  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 16  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 17  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 18  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# 19  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...

# %%
#check some initial rows 
df['location'].iloc[0]
# Out:
# 'C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample_nfo_2019-20_data\\complete_nfo_data_2019-01-01.pkl'

# %%
#split the path from _ 
df['location'].iloc[0].split('_')
# Out:
# ['C:\\Users\\deepe\\OneDrive\\Desktop\\NLP\\sample',
#  'nfo',
#  '2019-20',
#  'data\\complete',
#  'nfo',
#  'data',
#  '2019-01-01.pkl']

# %%
#choose the data part 
df['location'].iloc[0].split('_')[-1]
# Out:
# '2019-01-01.pkl'

# %%
# separate it from pkl and extract the date 
df['location'].iloc[0].split('_')[-1].split('.')
# Out:
# ['2019-01-01', 'pkl']

# %%
# apply for all rows using lambda function 
df['date_data'] = df['location'].apply(lambda x: x.split('_')[-1].split('.')[0])

# %%
df
# Out:
#                                              location   date_data
# 0   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-01
# 1   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-02
# 2   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-03
# 3   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-04
# 4   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-07
# 5   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-08
# 6   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-09
# 7   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-10
# 8   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-11
# 9   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-14
# 10  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-15
# 11  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-16
# 12  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-17
# 13  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-18
# 14  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-21
# 15  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-22
# 16  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-23
# 17  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-24
# 18  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-25
# 19  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...  2019-01-28

# %%
from dateutil.relativedelta import relativedelta, TH
#data date into date and time format 
df['date_data'] = df['date_data'].apply(lambda x: datetime.datetime.strptime(x,'%Y-%m-%d'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   20 non-null     object
#  1   date_data  20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 448.0+ bytes

# %%
# sort the date values 
df = df.sort_values(['date_data'])
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                                              location  date_data
# 0   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-01
# 1   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-02
# 2   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-03
# 3   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-04
# 4   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-07
# 5   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-08
# 6   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-09
# 7   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-10
# 8   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-11
# 9   C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-14
# 10  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-15
# 11  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-16
# 12  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-17
# 13  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-18
# 14  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-21
# 15  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-22
# 16  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-23
# 17  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-24
# 18  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-25
# 19  C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo... 2019-01-28

# %%
data = pd.read_pickle(df['location'].iloc[2])

# %%
data
# Out:
#                     ticker instrument_name instrument_type expiry_date  \
# 0       ACC19FEB1400PE.NFO             ACC              PE  2019-02-28
# 1       ACC19FEB1400PE.NFO             ACC              PE  2019-02-28
# 2       ACC19JAN1300PE.NFO             ACC              PE  2019-01-31
# 3       ACC19JAN1300PE.NFO             ACC              PE  2019-01-31
# 4       ACC19JAN1300PE.NFO             ACC              PE  2019-01-31
# ...                    ...             ...             ...         ...
# 283370         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 283371         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 283372         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 283373         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 283374         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
#
#         strike_price            datetime        date      time    open  \
# 0             1400.0 2019-01-03 10:48:00  2019-01-03  10:48:00   40.80
# 1             1400.0 2019-01-03 15:23:00  2019-01-03  15:23:00   30.00
# 2             1300.0 2019-01-03 09:25:00  2019-01-03  09:25:00    3.55
# 3             1300.0 2019-01-03 12:07:00  2019-01-03  12:07:00    3.55
# 4             1300.0 2019-01-03 14:06:00  2019-01-03  14:06:00    4.50
# ...              ...                 ...         ...       ...     ...
# 283370           0.0 2019-01-03 11:15:00  2019-01-03  11:15:00  468.60
# 283371           0.0 2019-01-03 11:19:00  2019-01-03  11:19:00  467.30
# 283372           0.0 2019-01-03 11:42:00  2019-01-03  11:42:00  468.65
# 283373           0.0 2019-01-03 13:41:00  2019-01-03  13:41:00  466.50
# 283374           0.0 2019-01-03 13:50:00  2019-01-03  13:50:00  464.35
#
#           high     low   close  volume  open interest  vix_close
# 0        40.80   40.80   40.80     400              0      16.66
# 1        30.00   30.00   30.00     400            400      16.80
# 2         3.55    3.55    3.55     400           1600      16.55
# 3         4.50    3.55    4.50     400           1600      16.95
# 4         4.75    4.50    4.75     400           2000      16.99
# ...        ...     ...     ...     ...            ...        ...
# 283370  468.60  467.30  467.30    7800          26000      16.75
# 283371  468.65  467.30  468.65    1300          33800      16.80
# 283372  468.65  466.50  466.50    1300          32500      16.94
# 283373  466.50  464.35  464.35    1300          33800      17.13
# 283374  464.35  464.05  464.05    2600          33800      17.10
#
# [283375 rows x 15 columns]

# %% [markdown]
# # Strategy
#
#
# Short Straddle, Short sell at 9:20 AM and SL at 20% per leg and exit time/ target taking time/ pnl booking time of 3:10 PM

# %%
a = datetime.time(9,20)
a
# Out:
# datetime.time(9, 20)

# %%
#python datetime function also requires date with it 
for index,row in df.iterrows():
    data = pd.read_pickle(row['location'])
    break 
    #we only need first row date

# %%
data
# Out:
#                     ticker instrument_name instrument_type expiry_date  \
# 0       ACC19FEB1300PE.NFO             ACC              PE  2019-02-28
# 1       ACC19FEB1700CE.NFO             ACC              CE  2019-02-28
# 2       ACC19JAN1360PE.NFO             ACC              PE  2019-01-31
# 3       ACC19JAN1380PE.NFO             ACC              PE  2019-01-31
# 4       ACC19JAN1380PE.NFO             ACC              PE  2019-01-31
# ...                    ...             ...             ...         ...
# 205270         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 205271         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 205272         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 205273        ZEEL-III.NFO            ZEEL             FUT  2019-03-28
# 205274        ZEEL-III.NFO            ZEEL             FUT  2019-03-28
#
#         strike_price            datetime        date      time    open  \
# 0             1300.0 2019-01-01 13:59:00  2019-01-01  13:59:00    4.90
# 1             1700.0 2019-01-01 13:58:00  2019-01-01  13:58:00    3.90
# 2             1360.0 2019-01-01 12:48:00  2019-01-01  12:48:00    7.25
# 3             1380.0 2019-01-01 12:06:00  2019-01-01  12:06:00   10.00
# 4             1380.0 2019-01-01 12:20:00  2019-01-01  12:20:00   10.80
# ...              ...                 ...         ...       ...     ...
# 205270           0.0 2019-01-01 15:12:00  2019-01-01  15:12:00  483.05
# 205271           0.0 2019-01-01 15:19:00  2019-01-01  15:19:00  483.05
# 205272           0.0 2019-01-01 15:26:00  2019-01-01  15:26:00  484.30
# 205273           0.0 2019-01-01 15:19:00  2019-01-01  15:19:00  486.00
# 205274           0.0 2019-01-01 15:26:00  2019-01-01  15:26:00  486.40
#
#           high     low   close  volume  open interest  vix_close expiry_type
# 0         4.90    4.90    4.90     400              0    16.1450
# 1         3.90    3.90    3.90     400              0    16.1525
# 2         7.25    7.25    7.25     400              0    16.1400
# 3        10.00   10.00   10.00     400            800    16.0600
# 4        10.80   10.80   10.80     400           1200    16.0700
# ...        ...     ...     ...     ...            ...        ...         ...
# 205270  483.05  483.05  483.05    1300          39000    15.3475          II
# 205271  484.30  483.05  484.30    2600          39000    15.2925          II
# 205272  484.40  484.30  484.40    1300          39000    15.2450          II
# 205273  486.30  486.00  486.30    2600              0    15.2925         III
# 205274  486.40  486.40  486.40    1300           2600    15.2450         III
#
# [205275 rows x 16 columns]

# %%
print(row) # retrieve date from this 
row['date_data'].date()
# Out:
# location     C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo...
# date_data                                  2019-01-01 00:00:00
# Name: 0, dtype: object
# datetime.date(2019, 1, 1)

# %%
# add this date into our datetime format of entry and exit time  
# a is the time we find above 
entry_time = datetime.datetime.combine(row['date_data'].date(),a)
entry_time
# Out:
# datetime.datetime(2019, 1, 1, 9, 20)

# %%
# add this date into our datetime format of entry and exit time  
b = datetime.time(3,10)
#b is the exit time
exit_time = datetime.datetime.combine(row['date_data'].date(),b)
exit_time
# Out:
# datetime.datetime(2019, 1, 1, 3, 10)

# %% [markdown]
# # Create a intraday trade log consists of
#
# 'Entry_Datetime','Future_Traded_Price','ATM','Days_to_Expiry','CE_Symbol','CE_Entry_Price','CE_Exit_Price','CE_Exit_Datetime','PE_Symbol','PE_Entry_Price','PE_Exit_Price','PE_Exit_Datetime','PnL'

# %%
intraday_trade_log = pd.DataFrame(columns = ['Entry_Datetime','Future_Traded_Price','ATM','Days_to_Expiry','CE_Symbol','CE_Entry_Price','CE_Exit_Price','CE_Exit_Datetime','PE_Symbol','PE_Entry_Price','PE_Exit_Price','PE_Exit_Datetime','PnL'])

# %%
intraday_trade_log.T
# Out:
# Empty DataFrame
# Columns: []
# Index: [Entry_Datetime, Future_Traded_Price, ATM, Days_to_Expiry, CE_Symbol, CE_Entry_Price, CE_Exit_Price, CE_Exit_Datetime, PE_Symbol, PE_Entry_Price, PE_Exit_Price, PE_Exit_Datetime, PnL]

# %%
#separate the later month expiry 
# I - Current Month 
# II - Next Month 
# III - NextToMonth 

data['expiry_type'] = np.where((data['instrument_type'] == 'FUT'), data['ticker'].apply(lambda x: x.split('-')[-1].split('.')[0]),'')
data
# Out:
#                     ticker instrument_name instrument_type expiry_date  \
# 0       ACC19FEB1300PE.NFO             ACC              PE  2019-02-28
# 1       ACC19FEB1700CE.NFO             ACC              CE  2019-02-28
# 2       ACC19JAN1360PE.NFO             ACC              PE  2019-01-31
# 3       ACC19JAN1380PE.NFO             ACC              PE  2019-01-31
# 4       ACC19JAN1380PE.NFO             ACC              PE  2019-01-31
# ...                    ...             ...             ...         ...
# 205270         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 205271         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 205272         ZEEL-II.NFO            ZEEL             FUT  2019-02-28
# 205273        ZEEL-III.NFO            ZEEL             FUT  2019-03-28
# 205274        ZEEL-III.NFO            ZEEL             FUT  2019-03-28
#
#         strike_price            datetime        date      time    open  \
# 0             1300.0 2019-01-01 13:59:00  2019-01-01  13:59:00    4.90
# 1             1700.0 2019-01-01 13:58:00  2019-01-01  13:58:00    3.90
# 2             1360.0 2019-01-01 12:48:00  2019-01-01  12:48:00    7.25
# 3             1380.0 2019-01-01 12:06:00  2019-01-01  12:06:00   10.00
# 4             1380.0 2019-01-01 12:20:00  2019-01-01  12:20:00   10.80
# ...              ...                 ...         ...       ...     ...
# 205270           0.0 2019-01-01 15:12:00  2019-01-01  15:12:00  483.05
# 205271           0.0 2019-01-01 15:19:00  2019-01-01  15:19:00  483.05
# 205272           0.0 2019-01-01 15:26:00  2019-01-01  15:26:00  484.30
# 205273           0.0 2019-01-01 15:19:00  2019-01-01  15:19:00  486.00
# 205274           0.0 2019-01-01 15:26:00  2019-01-01  15:26:00  486.40
#
#           high     low   close  volume  open interest  vix_close expiry_type
# 0         4.90    4.90    4.90     400              0    16.1450
# 1         3.90    3.90    3.90     400              0    16.1525
# 2         7.25    7.25    7.25     400              0    16.1400
# 3        10.00   10.00   10.00     400            800    16.0600
# 4        10.80   10.80   10.80     400           1200    16.0700
# ...        ...     ...     ...     ...            ...        ...         ...
# 205270  483.05  483.05  483.05    1300          39000    15.3475          II
# 205271  484.30  483.05  484.30    2600          39000    15.2925          II
# 205272  484.40  484.30  484.40    1300          39000    15.2450          II
# 205273  486.30  486.00  486.30    2600              0    15.2925         III
# 205274  486.40  486.40  486.40    1300           2600    15.2450         III
#
# [205275 rows x 16 columns]

# %%
set(data['expiry_type'])
# Out:
# {'', 'I', 'II', 'III'}

# %%
data.info()# check if datetime column is in right format or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205275 entries, 0 to 205274
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ticker           205275 non-null  object
#  1   instrument_name  205275 non-null  object
#  2   instrument_type  205275 non-null  object
#  3   expiry_date      205275 non-null  object
#  4   strike_price     205275 non-null  float64
#  5   datetime         205275 non-null  datetime64[ns]
#  6   date             205275 non-null  object
#  7   time             205275 non-null  object
#  8   open             205275 non-null  float64
#  9   high             205275 non-null  float64
#  10  low              205275 non-null  float64
#  11  close            205275 non-null  float64
#  12  volume           205275 non-null  int64
#  13  open interest    205275 non-null  int64
#  14  vix_close        205030 non-null  float64
#  15  expiry_type      205275 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(7)
# memory usage: 26.6+ MB

# %%
future_expiry_offset = 'I'
instrument = 'BANKNIFTY'
base = 100 #difference bw strike prices like in nifty 14000 14050 etc. 
futures_data = data[(data['instrument_type'] == 'FUT') & (data['instrument_name'] == instrument) & (data['expiry_type'] == future_expiry_offset)]
 
futures_data.reset_index(drop = True , inplace = True)

futures_data

# 376 rows implies 375 minutes of the market from 9:15 to 3:30
# Out:
#               ticker instrument_name instrument_type expiry_date  \
# 0    BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 1    BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 2    BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 3    BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 4    BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# ..               ...             ...             ...         ...
# 371  BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 372  BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 373  BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 374  BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
# 375  BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31
#
#      strike_price            datetime        date      time      open  \
# 0             0.0 2019-01-01 09:15:00  2019-01-01  09:15:00  27300.20
# 1             0.0 2019-01-01 09:16:00  2019-01-01  09:16:00  27317.75
# 2             0.0 2019-01-01 09:17:00  2019-01-01  09:17:00  27298.60
# 3             0.0 2019-01-01 09:18:00  2019-01-01  09:18:00  27307.00
# 4             0.0 2019-01-01 09:19:00  2019-01-01  09:19:00  27282.00
# ..            ...                 ...         ...       ...       ...
# 371           0.0 2019-01-01 15:26:00  2019-01-01  15:26:00  27524.10
# 372           0.0 2019-01-01 15:27:00  2019-01-01  15:27:00  27520.00
# 373           0.0 2019-01-01 15:28:00  2019-01-01  15:28:00  27520.80
# 374           0.0 2019-01-01 15:29:00  2019-01-01  15:29:00  27521.00
# 375           0.0 2019-01-01 15:30:00  2019-01-01  15:30:00  27526.00
#
#          high       low     close  volume  open interest  vix_close  \
# 0    27368.10  27300.20  27314.95   18300        1414860    16.1400
# 1    27322.10  27289.95  27299.35   11980        1414860    16.1425
# 2    27309.00  27296.25  27307.00   10760        1414860    16.1350
# 3    27308.75  27277.00  27282.00   13620        1424420    16.2600
# 4    27282.00  27257.50  27264.45   16040        1424420    16.2925
# ..        ...       ...       ...     ...            ...        ...
# 371  27526.00  27518.90  27519.20   20060        1670180    15.2450
# 372  27523.00  27518.55  27520.00   24900        1662920    15.2600
# 373  27531.00  27520.30  27523.00   25380        1662920    15.2525
# 374  27532.00  27520.95  27530.00   30520        1662920    15.2450
# 375  27526.00  27526.00  27526.00     600        1662920        NaN
#
#     expiry_type
# 0             I
# 1             I
# 2             I
# 3             I
# 4             I
# ..          ...
# 371           I
# 372           I
# 373           I
# 374           I
# 375           I
#
# [376 rows x 16 columns]

# %%
futures_data[futures_data['datetime'] == entry_time]
# Out:
#             ticker instrument_name instrument_type expiry_date  strike_price  \
# 5  BANKNIFTY-I.NFO       BANKNIFTY             FUT  2019-01-31           0.0
#
#              datetime        date      time     open     high      low  \
# 5 2019-01-01 09:20:00  2019-01-01  09:20:00  27260.0  27265.0  27250.0
#
#      close  volume  open interest  vix_close expiry_type
# 5  27265.0   21320        1424420    16.2875           I

# %%
futures_data[futures_data['datetime'] == entry_time]

atm = futures_data[futures_data['datetime'] == entry_time]['open'].iloc[0]
atm
# Out:
# 27260.0

# %%
#this 27263 is not readable convert it into base terms as strike price are in gap of 100 
atm = base*round(atm/base)
atm
# Out:
# 27300

# %%
nearest_expiry = row['date_data'].date() + relativedelta(weekday = TH(+1))
nearest_expiry
# Out:
# datetime.date(2019, 1, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205275 entries, 0 to 205274
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ticker           205275 non-null  object
#  1   instrument_name  205275 non-null  object
#  2   instrument_type  205275 non-null  object
#  3   expiry_date      205275 non-null  object
#  4   strike_price     205275 non-null  float64
#  5   datetime         205275 non-null  datetime64[ns]
#  6   date             205275 non-null  object
#  7   time             205275 non-null  object
#  8   open             205275 non-null  float64
#  9   high             205275 non-null  float64
#  10  low              205275 non-null  float64
#  11  close            205275 non-null  float64
#  12  volume           205275 non-null  int64
#  13  open interest    205275 non-null  int64
#  14  vix_close        205030 non-null  float64
#  15  expiry_type      205275 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(7)
# memory usage: 26.6+ MB

# %%
#there may be a case when there will be holiday on expiry so expiry happens one day before so will be subtracting a day or two 


ce_data = data[(data['instrument_type']== 'CE') & (data['instrument_name']== instrument) & ( (data['expiry_date']== nearest_expiry)| (data['expiry_date']==nearest_expiry - datetime.timedelta(days = 1)) |(data['expiry_date']== nearest_expiry - datetime.timedelta(days = 2))) & (data['strike_price']==atm)]
# Out:
#                             ticker instrument_name instrument_type  \
# 28630  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 28631  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 28632  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 28633  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 28634  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# ...                            ...             ...             ...
# 29000  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 29001  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 29002  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 29003  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
# 29004  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE
#
#       expiry_date  strike_price            datetime        date      time  \
# 28630  2019-01-03       27300.0 2019-01-01 09:15:00  2019-01-01  09:15:00
# 28631  2019-01-03       27300.0 2019-01-01 09:16:00  2019-01-01  09:16:00
# 28632  2019-01-03       27300.0 2019-01-01 09:17:00  2019-01-01  09:17:00
# 28633  2019-01-03       27300.0 2019-01-01 09:18:00  2019-01-01  09:18:00
# 28634  2019-01-03       27300.0 2019-01-01 09:19:00  2019-01-01  09:19:00
# ...           ...           ...                 ...         ...       ...
# 29000  2019-01-03       27300.0 2019-01-01 15:25:00  2019-01-01  15:25:00
# 29001  2019-01-03       27300.0 2019-01-01 15:26:00  2019-01-01  15:26:00
# 29002  2019-01-03       27300.0 2019-01-01 15:27:00  2019-01-01  15:27:00
# 29003  2019-01-03       27300.0 2019-01-01 15:28:00  2019-01-01  15:28:00
# 29004  2019-01-03       27300.0 2019-01-01 15:29:00  2019-01-01  15:29:00
#
#          open    high     low   close  volume  open interest  vix_close  \
# 28630  130.10  143.70  117.75  125.30   60160         582900    16.1400
# 28631  124.85  127.15  117.00  117.85   53120         582900    16.1425
# 28632  118.00  121.95  116.85  120.00   33620         582900    16.1350
# 28633  120.70  120.75  107.85  108.90   80540         634500    16.2600
# 28634  109.15  109.50   99.55  101.05   70160         634500    16.2925
# ...       ...     ...     ...     ...     ...            ...        ...
# 29000  199.90  200.00  197.65  199.10   38420         410000    15.2675
# 29001  199.70  200.00  197.60  198.05   25740         410000    15.2450
# 29002  198.60  201.00  197.95  200.00   26920         389060    15.2600
# 29003  200.85  200.85  199.45  200.00   21460         389060    15.2525
# 29004  200.65  203.55  200.10  203.05   22740         389060    15.2450
#
#       expiry_type
# 28630
# 28631
# 28632
# 28633
# 28634
# ...           ...
# 29000
# 29001
# 29002
# 29003
# 29004
#
# [375 rows x 16 columns]

# %%
# fetch call and put data 
# we have many expiry but we only need nearest expiry in ce

nearest_expiry = row['date_data'].date() + relativedelta(weekday = TH(+1))

ce_data = data[(data['instrument_type'] == 'CE') & (data['instrument_name'] == instrument) & ((data['expiry_date'] == nearest_expiry)|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=1))|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=2))) & (data['strike_price'] == atm)]
ce_data.reset_index(drop = True, inplace = True)
ce_data
# Out:
#                           ticker instrument_name instrument_type expiry_date  \
# 0    BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 1    BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 2    BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 3    BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 4    BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# ..                           ...             ...             ...         ...
# 370  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 371  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 372  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 373  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
# 374  BANKNIFTY03JAN1927300CE.NFO       BANKNIFTY              CE  2019-01-03
#
#      strike_price            datetime        date      time    open    high  \
# 0         27300.0 2019-01-01 09:15:00  2019-01-01  09:15:00  130.10  143.70
# 1         27300.0 2019-01-01 09:16:00  2019-01-01  09:16:00  124.85  127.15
# 2         27300.0 2019-01-01 09:17:00  2019-01-01  09:17:00  118.00  121.95
# 3         27300.0 2019-01-01 09:18:00  2019-01-01  09:18:00  120.70  120.75
# 4         27300.0 2019-01-01 09:19:00  2019-01-01  09:19:00  109.15  109.50
# ..            ...                 ...         ...       ...     ...     ...
# 370       27300.0 2019-01-01 15:25:00  2019-01-01  15:25:00  199.90  200.00
# 371       27300.0 2019-01-01 15:26:00  2019-01-01  15:26:00  199.70  200.00
# 372       27300.0 2019-01-01 15:27:00  2019-01-01  15:27:00  198.60  201.00
# 373       27300.0 2019-01-01 15:28:00  2019-01-01  15:28:00  200.85  200.85
# 374       27300.0 2019-01-01 15:29:00  2019-01-01  15:29:00  200.65  203.55
#
#         low   close  volume  open interest  vix_close expiry_type
# 0    117.75  125.30   60160         582900    16.1400
# 1    117.00  117.85   53120         582900    16.1425
# 2    116.85  120.00   33620         582900    16.1350
# 3    107.85  108.90   80540         634500    16.2600
# 4     99.55  101.05   70160         634500    16.2925
# ..      ...     ...     ...            ...        ...         ...
# 370  197.65  199.10   38420         410000    15.2675
# 371  197.60  198.05   25740         410000    15.2450
# 372  197.95  200.00   26920         389060    15.2600
# 373  199.45  200.00   21460         389060    15.2525
# 374  200.10  203.05   22740         389060    15.2450
#
# [375 rows x 16 columns]

# %%
pe_data = data[(data['instrument_type'] == 'PE') & (data['instrument_name'] == instrument) & ((data['expiry_date'] == nearest_expiry)|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=1))|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=2))) & (data['strike_price'] == atm)]
pe_data.reset_index(drop = True, inplace = True)
pe_data
# Out:
#                           ticker instrument_name instrument_type expiry_date  \
# 0    BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 1    BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 2    BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 3    BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 4    BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# ..                           ...             ...             ...         ...
# 370  BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 371  BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 372  BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 373  BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
# 374  BANKNIFTY03JAN1927300PE.NFO       BANKNIFTY              PE  2019-01-03
#
#      strike_price            datetime        date      time    open    high  \
# 0         27300.0 2019-01-01 09:15:00  2019-01-01  09:15:00  191.70  208.70
# 1         27300.0 2019-01-01 09:16:00  2019-01-01  09:16:00  198.90  214.00
# 2         27300.0 2019-01-01 09:17:00  2019-01-01  09:17:00  213.55  215.60
# 3         27300.0 2019-01-01 09:18:00  2019-01-01  09:18:00  206.00  223.50
# 4         27300.0 2019-01-01 09:19:00  2019-01-01  09:19:00  219.20  229.90
# ..            ...                 ...         ...       ...     ...     ...
# 370       27300.0 2019-01-01 15:26:00  2019-01-01  15:26:00   76.55   78.00
# 371       27300.0 2019-01-01 15:27:00  2019-01-01  15:27:00   77.55   78.30
# 372       27300.0 2019-01-01 15:28:00  2019-01-01  15:28:00   77.10   77.55
# 373       27300.0 2019-01-01 15:29:00  2019-01-01  15:29:00   76.50   77.75
# 374       27300.0 2019-01-01 15:30:00  2019-01-01  15:30:00   76.90   76.90
#
#         low   close  volume  open interest  vix_close expiry_type
# 0    160.90  198.50   22120         200500    16.1400
# 1    195.95  214.00   15080         200500    16.1425
# 2    203.35  206.40   12180         200500    16.1350
# 3    205.00  219.25   16960         212400    16.2600
# 4    219.20  229.60   12220         212400    16.2925
# ..      ...     ...     ...            ...        ...         ...
# 370   76.45   77.65   44640         463700    15.2450
# 371   76.55   76.75   38700         453640    15.2600
# 372   76.55   77.00   37600         453640    15.2525
# 373   75.15   76.00   52280         453640    15.2450
# 374   76.90   76.90     120         453640        NaN
#
# [375 rows x 16 columns]

# %% [markdown]
# # Backtesting

# %%
# to backtest this data we need call put and future price combined in data frame where we can interate each and every day so we need to merge call put and fut data side by side 
futures_data['close']
ce_data =  ce_data[['datetime','close']].set_index('datetime')
pe_data =  pe_data[['datetime','close']].set_index('datetime')

# %%
futures_data
# Out:
#                         close
# datetime
# 2019-01-01 09:15:00  27314.95
# 2019-01-01 09:16:00  27299.35
# 2019-01-01 09:17:00  27307.00
# 2019-01-01 09:18:00  27282.00
# 2019-01-01 09:19:00  27264.45
# ...                       ...
# 2019-01-01 15:26:00  27519.20
# 2019-01-01 15:27:00  27520.00
# 2019-01-01 15:28:00  27523.00
# 2019-01-01 15:29:00  27530.00
# 2019-01-01 15:30:00  27526.00
#
# [376 rows x 1 columns]

# %%
#set future index to be as date time be aware it can be executed once after that it will give errors
futures_data = futures_data[['datetime','close']].set_index('datetime')

# %%
futures_data
# Out:
#                         close
# datetime
# 2019-01-01 09:15:00  27314.95
# 2019-01-01 09:16:00  27299.35
# 2019-01-01 09:17:00  27307.00
# 2019-01-01 09:18:00  27282.00
# 2019-01-01 09:19:00  27264.45
# ...                       ...
# 2019-01-01 15:26:00  27519.20
# 2019-01-01 15:27:00  27520.00
# 2019-01-01 15:28:00  27523.00
# 2019-01-01 15:29:00  27530.00
# 2019-01-01 15:30:00  27526.00
#
# [376 rows x 1 columns]

# %%
intraday_data = pd.concat([futures_data,ce_data,pe_data],axis = 1)
intraday_data.columns = ['futures_close','ce_close','pe_close']
intraday_data
# Out:
#                      futures_close  ce_close  pe_close
# datetime
# 2019-01-01 09:15:00       27314.95    125.30    198.50
# 2019-01-01 09:16:00       27299.35    117.85    214.00
# 2019-01-01 09:17:00       27307.00    120.00    206.40
# 2019-01-01 09:18:00       27282.00    108.90    219.25
# 2019-01-01 09:19:00       27264.45    101.05    229.60
# ...                            ...       ...       ...
# 2019-01-01 15:26:00       27519.20    198.05     77.65
# 2019-01-01 15:27:00       27520.00    200.00     76.75
# 2019-01-01 15:28:00       27523.00    200.00     77.00
# 2019-01-01 15:29:00       27530.00    203.05     76.00
# 2019-01-01 15:30:00       27526.00       NaN     76.90
#
# [376 rows x 3 columns]

# %%
intraday_data.ffill() #use pd.setoptions for checking all rows if not working check some other function
# Out:
#                      futures_close  ce_close  pe_close
# datetime
# 2019-01-01 09:15:00       27314.95    125.30    198.50
# 2019-01-01 09:16:00       27299.35    117.85    214.00
# 2019-01-01 09:17:00       27307.00    120.00    206.40
# 2019-01-01 09:18:00       27282.00    108.90    219.25
# 2019-01-01 09:19:00       27264.45    101.05    229.60
# ...                            ...       ...       ...
# 2019-01-01 15:26:00       27519.20    198.05     77.65
# 2019-01-01 15:27:00       27520.00    200.00     76.75
# 2019-01-01 15:28:00       27523.00    200.00     77.00
# 2019-01-01 15:29:00       27530.00    203.05     76.00
# 2019-01-01 15:30:00       27526.00    203.05     76.90
#
# [376 rows x 3 columns]

# %%
intraday_data
# Out:
#                      futures_close  ce_close  pe_close
# datetime
# 2019-01-01 09:15:00       27314.95    125.30    198.50
# 2019-01-01 09:16:00       27299.35    117.85    214.00
# 2019-01-01 09:17:00       27307.00    120.00    206.40
# 2019-01-01 09:18:00       27282.00    108.90    219.25
# 2019-01-01 09:19:00       27264.45    101.05    229.60
# ...                            ...       ...       ...
# 2019-01-01 15:26:00       27519.20    198.05     77.65
# 2019-01-01 15:27:00       27520.00    200.00     76.75
# 2019-01-01 15:28:00       27523.00    200.00     77.00
# 2019-01-01 15:29:00       27530.00    203.05     76.00
# 2019-01-01 15:30:00       27526.00       NaN     76.90
#
# [376 rows x 3 columns]

# %%
intraday_data.reset_index(inplace = True)

# %%
intraday_data
# Out:
#                datetime  futures_close  ce_close  pe_close
# 0   2019-01-01 09:15:00       27314.95    125.30    198.50
# 1   2019-01-01 09:16:00       27299.35    117.85    214.00
# 2   2019-01-01 09:17:00       27307.00    120.00    206.40
# 3   2019-01-01 09:18:00       27282.00    108.90    219.25
# 4   2019-01-01 09:19:00       27264.45    101.05    229.60
# ..                  ...            ...       ...       ...
# 371 2019-01-01 15:26:00       27519.20    198.05     77.65
# 372 2019-01-01 15:27:00       27520.00    200.00     76.75
# 373 2019-01-01 15:28:00       27523.00    200.00     77.00
# 374 2019-01-01 15:29:00       27530.00    203.05     76.00
# 375 2019-01-01 15:30:00       27526.00       NaN     76.90
#
# [376 rows x 4 columns]

# %%
intraday_data[intraday_data['datetime'] == entry_time]
# Out:
#              datetime  futures_close  ce_close  pe_close
# 5 2019-01-01 09:20:00        27265.0     100.0     225.6

# %%
## whole code together

# %%
#import libraries
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from dateutil.relativedelta import relativedelta, TH

#fetch all the files from the diretory
path = pd.DataFrame(glob(r'C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo_2019-20_data\*'),columns=['location'])
path['data_date'] = path['location'].apply(lambda x: x.split('_')[-1].split('.')[0])
path['data_date'] = path['data_date'].apply(lambda x: datetime.datetime.strptime(x,'%Y-%m-%d'))
path = path.sort_values(['data_date'])
path.reset_index(drop=True,inplace=True)

intraday_trade_log = pd.DataFrame(columns=['Entry_Datetime','Future_Traded_Price','ATM','Days_to_Expiry','CE_Symbol','CE_Entry_Price','CE_Exit_Price','CE_Exit_Datetime','PE_Symbol','PE_Entry_Price','PE_Exit_Price','PE_Exit_Datetime','PnL'])

for index, row in path.iterrows():
    
    try:
        print(index)

        data = pd.read_pickle(row['location'])

        entry_datetime = datetime.datetime.combine(row['data_date'].date(),datetime.time(9,20))
        exit_datetime = datetime.datetime.combine(row['data_date'].date(),datetime.time(15,10))
        


        #I-CurrentMonth
        #II-NextMonth
        #III-NextToNextMonth
        data['expiry_type'] = np.where((data['instrument_type'] == 'FUT'),data['ticker'].apply(lambda x: x.split('-')[-1].split('.')[0]),'')

        future_expiry_offset = 'I'
        instrument = 'BANKNIFTY'
        base = 100

        futures_data = data[(data['instrument_type'] == 'FUT') & (data['instrument_name'] == instrument) & (data['expiry_type'] == future_expiry_offset)]
        futures_data.reset_index(drop=True,inplace=True)

       
    
    
     
        
        
        pseudo_data = data[(data['instrument_name'] == 'BANKNIFTY') & (data['datetime'] == entry_datetime)]

        # find the index of strike price whose price is near 150 Rs 
        pseudo_index= pseudo_data['open'].sub(150).abs().idxmin()
        
        #get the strike price 
        atm = data['strike_price'].iloc[pseudo_index]

        #this 27263 is not readable convert it into base terms as strike price are in gap of 100 
        atm = base*round(atm/base) 
        
    
        
        
        nearest_expiry = row['data_date'].date() + relativedelta(weekday=TH(+1))

        ce_data = data[(data['instrument_type'] == 'CE') & (data['instrument_name'] == instrument) & ((data['expiry_date'] == nearest_expiry)|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=1))|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=2))) & (data['strike_price'] == atm)]
        ce_data.reset_index(drop=True,inplace=True)

        pe_data = data[(data['instrument_type'] == 'PE') & (data['instrument_name'] == instrument) & ((data['expiry_date'] == nearest_expiry)|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=1))|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=2))) & (data['strike_price'] == atm)]
        pe_data.reset_index(drop=True,inplace=True)

        ce_symbol = ce_data['ticker'].iloc[0]
        pe_symbol = pe_data['ticker'].iloc[0]
        

        futures_data = futures_data[['datetime','close']].set_index('datetime')
        ce_data = ce_data[['datetime','close']].set_index('datetime')
        pe_data = pe_data[['datetime','close']].set_index('datetime')

        intraday_data = pd.concat([futures_data,ce_data,pe_data],axis=1)
        intraday_data.columns = ['futures_close','ce_close','pe_close']
        intraday_data = intraday_data.ffill()

        #pd.set_option('display.max_rows',400)

        intraday_data.reset_index(inplace=True)

        traded_prices = intraday_data[intraday_data['datetime'] == entry_datetime]

        futures_entry_price = traded_prices['futures_close'].iloc[0]
        ce_entry_price = traded_prices['ce_close'].iloc[0]
        pe_entry_price = traded_prices['pe_close'].iloc[0]

        stop_loss_percentage = 30/100 #change the percentage according to the requirements 

        ce_stop_loss = ce_entry_price + ce_entry_price*stop_loss_percentage

        pe_stop_loss = pe_entry_price + pe_entry_price*stop_loss_percentage

        entry_time_index = intraday_data[intraday_data['datetime'] == entry_datetime].index[0]

        exit_time_index = intraday_data[intraday_data['datetime'] == exit_datetime].index[0]

        intraday_data = intraday_data[entry_time_index:exit_time_index+1]

        intraday_data['ce_pnl'] = 0
        intraday_data['pe_pnl'] = 0

        intraday_data.reset_index(drop=True,inplace=True)

        ce_stop_loss_counter = 0
        pe_stop_loss_counter = 0
        ce_exit_datetime = ''
        pe_exit_datetime = ''
        ce_exit_price = 0
        pe_exit_price = 0
        ce_pnl = 0
        pe_pnl = 0
        pnl = 0

        for index, row in intraday_data.iterrows():
            ce_ltp = row['ce_close']
            pe_ltp = row['pe_close']

            #criterias for exit
            #none of the stoplosses were hit and time limit is reached
            if (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0) & (row['datetime'] == exit_datetime):

                ce_pnl = ce_entry_price - ce_ltp
                pe_pnl = pe_entry_price - pe_ltp

                ce_stop_loss_counter = 1
                pe_stop_loss_counter = 1

                ce_exit_datetime = row['datetime']
                pe_exit_datetime = row['datetime']

                ce_exit_price = ce_ltp
                pe_exit_price = pe_ltp

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                print('none of the stoplosses were hit and time limit is reached')

                pnl = ce_pnl + pe_pnl

                break

            #ce stop loss is hit and none were hit till now
            elif (ce_ltp >= ce_stop_loss) & (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0):

                ce_pnl = ce_entry_price - ce_stop_loss
                pe_pnl = pe_entry_price - pe_ltp

                ce_stop_loss_counter = 1

                ce_exit_datetime = row['datetime']

                ce_exit_price = ce_stop_loss
                
                #if one stoploss is hit then change the other one to its selling price 
                pe_stop_loss = pe_entry_price

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                print('ce stop loss is hit and none were hit till now')

                pnl = ce_pnl + pe_pnl


            #pe stop loss is hit and none were hit till now
            elif (pe_ltp >= pe_stop_loss) & (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0):

                ce_pnl = ce_entry_price - ce_ltp
                pe_pnl = pe_entry_price - pe_stop_loss

                pe_stop_loss_counter = 1

                pe_exit_datetime = row['datetime']
                
                
                #if one stoploss is hit then change the other one to its selling price 
                ce_stop_loss = ce_entry_price

                pe_exit_price = pe_stop_loss

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                print('pe stop loss is hit and none were hit till now')

                pnl = ce_pnl + pe_pnl


            #either ce or pe sl was hit and now other one is also hit
            elif (ce_stop_loss_counter == 1) & (pe_stop_loss_counter == 0):

                if (pe_ltp >= pe_stop_loss) & (row['datetime'] < exit_datetime):

                    pe_pnl = pe_entry_price - pe_stop_loss

                    pe_stop_loss_counter = 1

                    pe_exit_price = pe_stop_loss

                    pe_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('ce sl was hit and now other one is also hit')

                    pnl = ce_pnl + pe_pnl

                    break


                elif (row['datetime'] == exit_datetime):

                    pe_pnl = pe_entry_price - pe_ltp

                    pe_stop_loss_counter = 1

                    pe_exit_price = pe_ltp

                    pe_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('pe sl was hit and now other exited based on exit time')

                    pnl = ce_pnl + pe_pnl

                    break


            #either ce or pe sl was hit and now other one is also hit
            elif (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 1):

                if (ce_ltp >= ce_stop_loss) & (row['datetime'] < exit_datetime):

                    ce_pnl = ce_entry_price - ce_stop_loss

                    ce_stop_loss_counter = 1

                    ce_exit_price = ce_stop_loss

                    ce_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('pe sl was hit and now other one is also hit')

                    pnl = ce_pnl + pe_pnl

                    break


                elif (row['datetime'] == exit_datetime):

                    ce_pnl = ce_entry_price - ce_ltp

                    ce_stop_loss_counter = 1

                    ce_exit_price = ce_ltp

                    ce_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('ce sl was hit and now other exited based on exit time')

                    pnl = ce_pnl + pe_pnl

                    break


            #update the pnl during the normal course of the day
            elif (((ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0)) | ((ce_stop_loss_counter == 1) & (pe_stop_loss_counter == 0))  | ((ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 1)) | ((ce_stop_loss_counter == 1) & (pe_stop_loss_counter == 1))) or row['datetime'] <= exit_datetime:

                ce_pnl = ce_entry_price - ce_ltp
                pe_pnl = pe_entry_price - pe_ltp

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                pnl = ce_pnl + pe_pnl

        intraday_trade_log = intraday_trade_log.append({'Entry_Datetime':entry_datetime,
                                                        'Future_Traded_Price':futures_entry_price,
                                                        'ATM':atm,
                                                        'Days_to_Expiry':(nearest_expiry - entry_datetime.date()).days,
                                                        'CE_Symbol':ce_symbol,
                                                        'CE_Entry_Price':ce_entry_price,
                                                        'CE_Exit_Price':ce_exit_price,
                                                        'CE_Exit_Datetime':ce_exit_datetime,
                                                        'PE_Symbol':pe_symbol,
                                                        'PE_Entry_Price':pe_entry_price,
                                                        'PE_Exit_Price':pe_exit_price,
                                                        'PE_Exit_Datetime':pe_exit_datetime,
                                                        'PnL':pnl},ignore_index=True)
    except Exception as e:
        print(e)
        print(row['location'])

intraday_trade_log['PnL'].cumsum().plot()
# Out:
# 0
# pe stop loss is hit and none were hit till now
# pe sl was hit and now other one is also hit
# 1
# pe stop loss is hit and none were hit till now
# pe sl was hit and now other one is also hit
# 2
# ce stop loss is hit and none were hit till now
# ce sl was hit and now other one is also hit
# 3
# ce stop loss is hit and none were hit till now
# pe sl was hit and now other exited based on exit time
# 4
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 5
# ce stop loss is hit and none were hit till now
# pe sl was hit and now other exited based on exit time
# 6
# none of the stoplosses were hit and time limit is reached
# 7
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 8
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 9
# none of the stoplosses were hit and time limit is reached
# 10
# none of the stoplosses were hit and time limit is reached
# 11
# none of the stoplosses were hit and time limit is reached
# 12
# pe stop loss is hit and none were hit till now
# pe sl was hit and now other one is also hit
# 13
# none of the stoplosses were hit and time limit is reached
# 14
# ce stop loss is hit and none were hit till now
# pe sl was hit and now other exited based on exit time
# 15
# none of the stoplosses were hit and time limit is reached
# 16
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 17
# ce stop loss is hit and none were hit till now
# ce sl was hit and now other one is also hit
# 18
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 19
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# <AxesSubplot:>

# %%
#import libraries
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from dateutil.relativedelta import relativedelta, TH

#fetch all the files from the diretory
path = pd.DataFrame(glob(r'C:\Users\deepe\OneDrive\Desktop\NLP\sample_nfo_2019-20_data\*'),columns=['location'])
path['data_date'] = path['location'].apply(lambda x: x.split('_')[-1].split('.')[0])
path['data_date'] = path['data_date'].apply(lambda x: datetime.datetime.strptime(x,'%Y-%m-%d'))
path = path.sort_values(['data_date'])
path.reset_index(drop=True,inplace=True)

intraday_trade_log = pd.DataFrame(columns=['Entry_Datetime','Future_Traded_Price','ATM','Days_to_Expiry','CE_Symbol','CE_Entry_Price','CE_Exit_Price','CE_Exit_Datetime','PE_Symbol','PE_Entry_Price','PE_Exit_Price','PE_Exit_Datetime','PnL'])

for index, row in path.iterrows():
    
    try:
        print(index)

        data = pd.read_pickle(row['location'])

        entry_datetime = datetime.datetime.combine(row['data_date'].date(),datetime.time(9,20))
        exit_datetime = datetime.datetime.combine(row['data_date'].date(),datetime.time(15,10))


        #I-CurrentMonth
        #II-NextMonth
        #III-NextToNextMonth
        data['expiry_type'] = np.where((data['instrument_type'] == 'FUT'),data['ticker'].apply(lambda x: x.split('-')[-1].split('.')[0]),'')

        future_expiry_offset = 'I'
        instrument = 'BANKNIFTY'
        base = 100

        futures_data = data[(data['instrument_type'] == 'FUT') & (data['instrument_name'] == instrument) & (data['expiry_type'] == future_expiry_offset)]
        futures_data.reset_index(drop=True,inplace=True)

        pseudo_data = data[(data['instrument_name'] == 'BANKNIFTY') & (data['datetime'] == entry_datetime)]

        # find the index of strike price whose price is near 150 Rs 
        pseudo_index= pseudo_data['open'].sub(150).abs().idxmin()
        
        #get the strike price 
        atm = data['strike_price'].iloc[pseudo_index]

        #this 27263 is not readable convert it into base terms as strike price are in gap of 100 
        atm = base*round(atm/base) 
        

        nearest_expiry = row['data_date'].date() + relativedelta(weekday=TH(+1))

        ce_data = data[(data['instrument_type'] == 'CE') & (data['instrument_name'] == instrument) & ((data['expiry_date'] == nearest_expiry)|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=1))|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=2))) & (data['strike_price'] == atm)]
        ce_data.reset_index(drop=True,inplace=True)

        pe_data = data[(data['instrument_type'] == 'PE') & (data['instrument_name'] == instrument) & ((data['expiry_date'] == nearest_expiry)|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=1))|(data['expiry_date'] == nearest_expiry - datetime.timedelta(days=2))) & (data['strike_price'] == atm)]
        pe_data.reset_index(drop=True,inplace=True)

        ce_symbol = ce_data['ticker'].iloc[0]
        pe_symbol = pe_data['ticker'].iloc[0]
        

        futures_data = futures_data[['datetime','close']].set_index('datetime')
        ce_data = ce_data[['datetime','close']].set_index('datetime')
        pe_data = pe_data[['datetime','close']].set_index('datetime')

        intraday_data = pd.concat([futures_data,ce_data,pe_data],axis=1)
        intraday_data.columns = ['futures_close','ce_close','pe_close']
        intraday_data = intraday_data.ffill()

        #pd.set_option('display.max_rows',400)

        intraday_data.reset_index(inplace=True)

        traded_prices = intraday_data[intraday_data['datetime'] == entry_datetime]

        futures_entry_price = traded_prices['futures_close'].iloc[0]
        ce_entry_price = traded_prices['ce_close'].iloc[0]
        pe_entry_price = traded_prices['pe_close'].iloc[0]

        stop_loss_percentage = 20/100

        ce_stop_loss = ce_entry_price + ce_entry_price*stop_loss_percentage

        pe_stop_loss = pe_entry_price + pe_entry_price*stop_loss_percentage

        entry_time_index = intraday_data[intraday_data['datetime'] == entry_datetime].index[0]

        exit_time_index = intraday_data[intraday_data['datetime'] == exit_datetime].index[0]

        intraday_data = intraday_data[entry_time_index:exit_time_index+1]

        intraday_data['ce_pnl'] = 0
        intraday_data['pe_pnl'] = 0

        intraday_data.reset_index(drop=True,inplace=True)

        ce_stop_loss_counter = 0
        pe_stop_loss_counter = 0
        ce_exit_datetime = ''
        pe_exit_datetime = ''
        ce_exit_price = 0
        pe_exit_price = 0
        ce_pnl = 0
        pe_pnl = 0
        pnl = 0

        for index, row in intraday_data.iterrows():
            ce_ltp = row['ce_close']
            pe_ltp = row['pe_close']

            #criterias for exit
            #none of the stoplosses were hit and time limit is reached
            if (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0) & (row['datetime'] == exit_datetime):

                ce_pnl = ce_entry_price - ce_ltp
                pe_pnl = pe_entry_price - pe_ltp

                ce_stop_loss_counter = 1
                pe_stop_loss_counter = 1

                ce_exit_datetime = row['datetime']
                pe_exit_datetime = row['datetime']

                ce_exit_price = ce_ltp
                pe_exit_price = pe_ltp

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                print('none of the stoplosses were hit and time limit is reached')

                pnl = ce_pnl + pe_pnl

                break

            #ce stop loss is hit and none were hit till now
            elif (ce_ltp >= ce_stop_loss) & (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0):

                ce_pnl = ce_entry_price - ce_stop_loss
                pe_pnl = pe_entry_price - pe_ltp

                ce_stop_loss_counter = 1

                ce_exit_datetime = row['datetime']

                ce_exit_price = ce_stop_loss

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                print('ce stop loss is hit and none were hit till now')

                pnl = ce_pnl + pe_pnl


            #pe stop loss is hit and none were hit till now
            elif (pe_ltp >= pe_stop_loss) & (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0):

                ce_pnl = ce_entry_price - ce_ltp
                pe_pnl = pe_entry_price - pe_stop_loss

                pe_stop_loss_counter = 1

                pe_exit_datetime = row['datetime']

                pe_exit_price = pe_stop_loss

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                print('pe stop loss is hit and none were hit till now')

                pnl = ce_pnl + pe_pnl


            #either ce or pe sl was hit and now other one is also hit
            elif (ce_stop_loss_counter == 1) & (pe_stop_loss_counter == 0):

                if (pe_ltp >= pe_stop_loss) & (row['datetime'] < exit_datetime):

                    pe_pnl = pe_entry_price - pe_stop_loss

                    pe_stop_loss_counter = 1

                    pe_exit_price = pe_stop_loss

                    pe_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('ce sl was hit and now other one is also hit')

                    pnl = ce_pnl + pe_pnl

                    break


                elif (row['datetime'] == exit_datetime):

                    pe_pnl = pe_entry_price - pe_ltp

                    pe_stop_loss_counter = 1

                    pe_exit_price = pe_ltp

                    pe_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('pe sl was hit and now other exited based on exit time')

                    pnl = ce_pnl + pe_pnl

                    break


            #either ce or pe sl was hit and now other one is also hit
            elif (ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 1):

                if (ce_ltp >= ce_stop_loss) & (row['datetime'] < exit_datetime):

                    ce_pnl = ce_entry_price - ce_stop_loss

                    ce_stop_loss_counter = 1

                    ce_exit_price = ce_stop_loss

                    ce_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('pe sl was hit and now other one is also hit')

                    pnl = ce_pnl + pe_pnl

                    break


                elif (row['datetime'] == exit_datetime):

                    ce_pnl = ce_entry_price - ce_ltp

                    ce_stop_loss_counter = 1

                    ce_exit_price = ce_ltp

                    ce_exit_datetime = row['datetime']

                    intraday_data.loc[index,'ce_pnl'] = ce_pnl
                    intraday_data.loc[index,'pe_pnl'] = pe_pnl

                    print('ce sl was hit and now other exited based on exit time')

                    pnl = ce_pnl + pe_pnl

                    break


            #update the pnl during the normal course of the day
            elif (((ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 0)) | ((ce_stop_loss_counter == 1) & (pe_stop_loss_counter == 0))  | ((ce_stop_loss_counter == 0) & (pe_stop_loss_counter == 1)) | ((ce_stop_loss_counter == 1) & (pe_stop_loss_counter == 1))) or row['datetime'] <= exit_datetime:

                ce_pnl = ce_entry_price - ce_ltp
                pe_pnl = pe_entry_price - pe_ltp

                intraday_data.loc[index,'ce_pnl'] = ce_pnl
                intraday_data.loc[index,'pe_pnl'] = pe_pnl

                pnl = ce_pnl + pe_pnl

        intraday_trade_log = intraday_trade_log.append({'Entry_Datetime':entry_datetime,
                                                        'Future_Traded_Price':futures_entry_price,
                                                        'ATM':atm,
                                                        'Days_to_Expiry':(nearest_expiry - entry_datetime.date()).days,
                                                        'CE_Symbol':ce_symbol,
                                                        'CE_Entry_Price':ce_entry_price,
                                                        'CE_Exit_Price':ce_exit_price,
                                                        'CE_Exit_Datetime':ce_exit_datetime,
                                                        'PE_Symbol':pe_symbol,
                                                        'PE_Entry_Price':pe_entry_price,
                                                        'PE_Exit_Price':pe_exit_price,
                                                        'PE_Exit_Datetime':pe_exit_datetime,
                                                        'PnL':pnl},ignore_index=True)
    except Exception as e:
        print(e)
        print(row['location'])

intraday_trade_log['PnL'].cumsum().plot()
# Out:
# 0
# pe stop loss is hit and none were hit till now
# pe sl was hit and now other one is also hit
# 1
# pe stop loss is hit and none were hit till now
# pe sl was hit and now other one is also hit
# 2
# ce stop loss is hit and none were hit till now
# ce sl was hit and now other one is also hit
# 3
# ce stop loss is hit and none were hit till now
# pe sl was hit and now other exited based on exit time
# 4
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 5
# ce stop loss is hit and none were hit till now
# pe sl was hit and now other exited based on exit time
# 6
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 7
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 8
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 9
# none of the stoplosses were hit and time limit is reached
# 10
# none of the stoplosses were hit and time limit is reached
# 11
# ce stop loss is hit and none were hit till now
# pe sl was hit and now other exited based on exit time
# 12
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 13
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 14
# ce stop loss is hit and none were hit till now
# pe sl was hit and now other exited based on exit time
# 15
# none of the stoplosses were hit and time limit is reached
# 16
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 17
# pe stop loss is hit and none were hit till now
# pe sl was hit and now other one is also hit
# 18
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# 19
# pe stop loss is hit and none were hit till now
# ce sl was hit and now other exited based on exit time
# <AxesSubplot:>
